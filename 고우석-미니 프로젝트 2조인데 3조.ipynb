# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import koreanize_matplotlib
import seaborn as sns

# %%
file='../SQL/data/ord2.csv'

# %%
ordinary=pd.read_csv(file)

# %%
ordinary
# Out:
#    Unnamed: 0 2007 Unnamed: 2 2008 Unnamed: 4 2009 Unnamed: 6 2010 Unnamed: 8  \
# 0         NaN   빈도         비중   빈도         비중   빈도         비중   빈도         비중
# 1          서울  490         23  655       24.9  668       23.3  721       23.1
# 2          부산  207        9.7  267       10.1  314         11  339       10.9
# 3          대구  167        7.8  191        7.3  225        7.8  230        7.4
# 4          인천  184        8.6  216        8.2  240        8.4  264        8.5
# 5          광주  112        5.3  129        4.9  126        4.4  134        4.3
# 6          대전  116        5.5  129        4.9  140        4.9  152        4.9
# 7          울산   51        2.4   56        2.1   57          2   68        2.2
# 8          경기  441       20.7  529       20.1  603         21  669       21.4
# 9          강원   36        1.7   34        1.3   35        1.2   36        1.2
# 10         충북   42          2   68        2.6   69        2.4   77        2.5
# ...

# %%
ordinary.stack()
# Out:
# 0   2007            빈도
#     Unnamed: 2      비중
#     2008            빈도
#     Unnamed: 4      비중
#     2009            빈도
#                   ...
# 16  Unnamed: 24    0.6
#     2019            35
#     Unnamed: 26    0.7
#     2020            33
#     Unnamed: 28    0.6
# Length: 492, dtype: object

# %%
ordinary1=ordinary[['Unnamed: 0','Unnamed: 2','Unnamed: 4','Unnamed: 6','Unnamed: 8','Unnamed: 10','Unnamed: 12','Unnamed: 14','Unnamed: 16','Unnamed: 18','Unnamed: 20','Unnamed: 22','Unnamed: 24','Unnamed: 26','Unnamed: 28']]

# %%
ordinary1
# Out:
#    Unnamed: 0 Unnamed: 2 Unnamed: 4 Unnamed: 6 Unnamed: 8 Unnamed: 10  \
# 0         NaN         비중         비중         비중         비중          비중
# 1          서울         23       24.9       23.3       23.1        21.8
# 2          부산        9.7       10.1         11       10.9        11.6
# 3          대구        7.8        7.3        7.8        7.4         6.8
# 4          인천        8.6        8.2        8.4        8.5         8.4
# 5          광주        5.3        4.9        4.4        4.3         4.6
# 6          대전        5.5        4.9        4.9        4.9           5
# 7          울산        2.4        2.1          2        2.2         2.4
# 8          경기       20.7       20.1         21       21.4        20.8
# 9          강원        1.7        1.3        1.2        1.2         1.5
# 10         충북          2        2.6        2.4        2.5         2.5
# 11         충남        3.2        2.9        2.8        2.9         2.9
# ...

# %%
ordinary1.columns=['도시','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020']

# %%
ordinary2=ordinary1.iloc[1:17]

# %%
ordinary2
# Out:
#     도시  2007  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  \
# 1   서울    23  24.9  23.3  23.1  21.8  22.1  21.9  21.1  20.6  22.1  21.1
# 2   부산   9.7  10.1    11  10.9  11.6  11.4  11.1  11.2  11.2  11.3  10.7
# 3   대구   7.8   7.3   7.8   7.4   6.8   6.7   6.7   6.5   6.8   6.1   6.3
# 4   인천   8.6   8.2   8.4   8.5   8.4   8.6     9     9   9.1   9.2   9.1
# 5   광주   5.3   4.9   4.4   4.3   4.6   4.4   4.7   4.7   4.3   4.5   4.4
# 6   대전   5.5   4.9   4.9   4.9     5   5.2   5.4   5.6   5.4     5     5
# 7   울산   2.4   2.1     2   2.2   2.4   2.6   2.3   2.3   2.4   2.1   2.1
# 8   경기  20.7  20.1    21  21.4  20.8  20.9  20.9  21.1  21.9  21.4  22.3
# 9   강원   1.7   1.3   1.2   1.2   1.5   1.4   1.4   1.5   1.6   1.7   1.7
# 10  충북     2   2.6   2.4   2.5   2.5   2.4   2.4   2.5   2.5   2.4   2.6
# 11  충남   3.2   2.9   2.8   2.9   2.9   2.9   2.9     3   2.9   2.9     3
# 12  전북   1.6   1.7   1.9   1.7   1.9   1.7     2   1.9   2.1   2.1     2
# ...

# %%
ordinary2.columns
# Out:
# Index(['도시', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
ordinary3=ordinary2.set_index('도시')

# %%
ordinary3
# Out:
#     2007  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018  \
# 도시
# 서울    23  24.9  23.3  23.1  21.8  22.1  21.9  21.1  20.6  22.1  21.1  21.2
# 부산   9.7  10.1    11  10.9  11.6  11.4  11.1  11.2  11.2  11.3  10.7  10.7
# 대구   7.8   7.3   7.8   7.4   6.8   6.7   6.7   6.5   6.8   6.1   6.3   6.4
# 인천   8.6   8.2   8.4   8.5   8.4   8.6     9     9   9.1   9.2   9.1   8.7
# 광주   5.3   4.9   4.4   4.3   4.6   4.4   4.7   4.7   4.3   4.5   4.4   4.5
# 대전   5.5   4.9   4.9   4.9     5   5.2   5.4   5.6   5.4     5     5     5
# 울산   2.4   2.1     2   2.2   2.4   2.6   2.3   2.3   2.4   2.1   2.1     2
# 경기  20.7  20.1    21  21.4  20.8  20.9  20.9  21.1  21.9  21.4  22.3  22.8
# 강원   1.7   1.3   1.2   1.2   1.5   1.4   1.4   1.5   1.6   1.7   1.7   1.6
# 충북     2   2.6   2.4   2.5   2.5   2.4   2.4   2.5   2.5   2.4   2.6   2.6
# 충남   3.2   2.9   2.8   2.9   2.9   2.9   2.9     3   2.9   2.9     3     3
# ...

# %%
ordinary3['2007'].astype('float')
ordinary3['2008'].astype('float')
ordinary3['2009'].astype('float')
ordinary3['2010'].astype('float')
ordinary3['2011'].astype('float')
ordinary3['2012'].astype('float')
ordinary3['2013'].astype('float')
ordinary3['2014'].astype('float')
ordinary3['2015'].astype('float')
ordinary3['2016'].astype('float')
ordinary3['2017'].astype('float')
ordinary3['2018'].astype('float')
ordinary3['2019'].astype('float')
ordinary3['2020'].astype('float')

ordinary4=ordinary3.astype('float')

# %%
ordinary4
# Out:
#     2007  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018  \
# 도시
# 서울  23.0  24.9  23.3  23.1  21.8  22.1  21.9  21.1  20.6  22.1  21.1  21.2
# 부산   9.7  10.1  11.0  10.9  11.6  11.4  11.1  11.2  11.2  11.3  10.7  10.7
# 대구   7.8   7.3   7.8   7.4   6.8   6.7   6.7   6.5   6.8   6.1   6.3   6.4
# 인천   8.6   8.2   8.4   8.5   8.4   8.6   9.0   9.0   9.1   9.2   9.1   8.7
# 광주   5.3   4.9   4.4   4.3   4.6   4.4   4.7   4.7   4.3   4.5   4.4   4.5
# 대전   5.5   4.9   4.9   4.9   5.0   5.2   5.4   5.6   5.4   5.0   5.0   5.0
# 울산   2.4   2.1   2.0   2.2   2.4   2.6   2.3   2.3   2.4   2.1   2.1   2.0
# 경기  20.7  20.1  21.0  21.4  20.8  20.9  20.9  21.1  21.9  21.4  22.3  22.8
# 강원   1.7   1.3   1.2   1.2   1.5   1.4   1.4   1.5   1.6   1.7   1.7   1.6
# 충북   2.0   2.6   2.4   2.5   2.5   2.4   2.4   2.5   2.5   2.4   2.6   2.6
# 충남   3.2   2.9   2.8   2.9   2.9   2.9   2.9   3.0   2.9   2.9   3.0   3.0
# ...

# %%
len(ordinary4.loc['서울'])
# Out:
# 14

# %%
labels=['서울','부산','대구','인천','광주','대전','울산','경기','강원','충북','충남','전북','전남','경북','경남','제주']
plt.figure(figsize=(15,15))
plt.pie(ordinary4['2020'], autopct='%1.1f%%',labels=labels,
       shadow={'ox': -0.04, 'edgecolor': 'none', 'shade': 0.9}, startangle=90)
plt.title('2020년 취업자 비중 지역별 분류')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.bar(ordinary4.columns,ordinary4.loc['경기'])
plt.title('경기 지역의 취업자 비중')
plt.xlabel('연도')
plt.ylabel('비중(%)')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(10,8))
plt.bar(ordinary4.columns,ordinary4.loc['서울'])
plt.title('서울 지역의 취업자 비중')
plt.xlabel('연도')
plt.ylabel('비중(%)')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
len(ordinary4.columns)
# Out:
# 14

# %%
plt.figure(figsize=(10,8))
plt.bar(ordinary4.columns,ordinary4.loc['부산'])
plt.title('부산 지역의 취업자 비중')
plt.xlabel('연도')
plt.ylabel('비중(%)')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(10,8))
plt.bar(ordinary4.columns,ordinary4.loc['부산'])
plt.title('대구 지역의 취업자 비중')
plt.xlabel('연도')
plt.ylabel('비중(%)')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(10,8))
plt.bar(ordinary4.columns,ordinary4.loc['인천'])
plt.title('인천 지역의 취업자 비중')
plt.xlabel('연도')
plt.ylabel('비중(%)')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(10,8))
plt.bar(ordinary4.columns,ordinary4.loc['광주'])
plt.title('광주 지역의 취업자 비중')
plt.xlabel('연도')
plt.ylabel('비중(%)')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(10,8))
plt.bar(ordinary4.columns,ordinary4.loc['대전'])
plt.title('대전 지역의 취업자 비중')
plt.xlabel('연도')
plt.ylabel('비중(%)')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(10,8))
plt.bar(ordinary4.columns,ordinary4.loc['울산'])
plt.title('울산 지역의 취업자 비중')
plt.xlabel('연도')
plt.ylabel('비중(%)')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(10,8))
plt.bar(ordinary4.columns,ordinary4.loc['경기'])
plt.title('경기 지역의 취업자 비중')
plt.xlabel('연도')
plt.ylabel('비중(%)')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(10,8))
plt.bar(ordinary4.columns,ordinary4.loc['강원'])
plt.title('강원 지역의 취업자 비중')
plt.xlabel('연도')
plt.ylabel('비중(%)')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(10,8))
plt.bar(ordinary4.columns,ordinary4.loc['충북'])
plt.title('충북 지역의 취업자 비중')
plt.xlabel('연도')
plt.ylabel('비중(%)')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(10,8))
plt.bar(ordinary4.columns,ordinary4.loc['충남'])
plt.title('충남 지역의 취업자 비중')
plt.xlabel('연도')
plt.ylabel('비중(%)')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(10,8))
plt.bar(ordinary4.columns,ordinary4.loc['전북'])
plt.title('전북 지역의 취업자 비중')
plt.xlabel('연도')
plt.ylabel('비중(%)')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(10,8))
plt.bar(ordinary4.columns,ordinary4.loc['전남'])
plt.title('전남 지역의 취업자 비중')
plt.xlabel('연도')
plt.ylabel('비중(%)')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(10,8))
plt.bar(ordinary4.columns,ordinary4.loc['경북'])
plt.title('경북 지역의 취업자 비중')
plt.xlabel('연도')
plt.ylabel('비중(%)')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(10,8))
plt.bar(ordinary4.columns,ordinary4.loc['경남'])
plt.title('경남 지역의 취업자 비중')
plt.xlabel('연도')
plt.ylabel('비중(%)')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(10,8))
plt.bar(ordinary4.columns,ordinary4.loc['제주'])
plt.title('제주 지역의 취업자 비중')
plt.xlabel('연도')
plt.ylabel('비중(%)')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# 학력 분류

# %%
file2='../SQL/data/study2.csv'

# %%
study=pd.read_csv(file2,header=[0])

# %%
study
# Out:
#     시도별           항목    시점  초졸이하   중졸    고졸  대졸이상  전문대졸  대학교졸이상
# 0    서울  경제활동인구 (천명)  2013   272  409  1901  2775   657    2118
# 1    서울  경제활동인구 (천명)  2014   257  406  1901  2886   665    2221
# 2    서울  경제활동인구 (천명)  2015   257  380  1891  2863   634    2228
# 3    서울  경제활동인구 (천명)  2016   236  355  1878  2903   605    2299
# 4    서울  경제활동인구 (천명)  2017   232  345  1847  2972   592    2380
# ..   ..          ...   ...   ...  ...   ...   ...   ...     ...
# 178  제주  경제활동인구 (천명)  2019    40   27   137   186    82     105
# 179  제주  경제활동인구 (천명)  2020    42   26   137   183    73     111
# 180  제주  경제활동인구 (천명)  2021    37   24   139   195    71     124
# 181  제주  경제활동인구 (천명)  2022    30   22   148   210    72     138
# 182  제주  경제활동인구 (천명)  2023    25   23   141   220    81     139
#
# [183 rows x 9 columns]

# %%
study1=study.fillna('')

# %%
study2=study1[['시도별','시점','초졸이하','중졸','고졸','대졸이상','전문대졸','대학교졸이상']]
study2
# Out:
#     시도별    시점  초졸이하   중졸    고졸  대졸이상  전문대졸  대학교졸이상
# 0    서울  2013   272  409  1901  2775   657    2118
# 1    서울  2014   257  406  1901  2886   665    2221
# 2    서울  2015   257  380  1891  2863   634    2228
# 3    서울  2016   236  355  1878  2903   605    2299
# 4    서울  2017   232  345  1847  2972   592    2380
# ..   ..   ...   ...  ...   ...   ...   ...     ...
# 178  제주  2019    40   27   137   186    82     105
# 179  제주  2020    42   26   137   183    73     111
# 180  제주  2021    37   24   139   195    71     124
# 181  제주  2022    30   22   148   210    72     138
# 182  제주  2023    25   23   141   220    81     139
#
# [183 rows x 8 columns]

# %%
seoul=study2[study2['시도별']=='서울']
busan=study2[study2['시도별']=='부산']
daegu=study2[study2['시도별']=='대구']
incheon=study2[study2['시도별']=='인천']
gwangju=study2[study2['시도별']=='광주']
daejun=study2[study2['시도별']=='대전']
ulsan=study2[study2['시도별']=='울산']
sejong=study2[study2['시도별']=='세종']
gyeongi=study2[study2['시도별']=='경기']
ganwon=study2[study2['시도별']=='강원']
chungbuk=study2[study2['시도별']=='충북']
chungnam=study2[study2['시도별']=='충남']
junbook=study2[study2['시도별']=='전북']
jeonnam=study2[study2['시도별']=='전남']
gyeongbuk=study2[study2['시도별']=='경북']
gyeongnam=study2[study2['시도별']=='경남']
jeju=study2[study2['시도별']=='제주']

# %%
seoul
# Out:
#    시도별    시점  초졸이하   중졸    고졸  대졸이상  전문대졸  대학교졸이상
# 0   서울  2013   272  409  1901  2775   657    2118
# 1   서울  2014   257  406  1901  2886   665    2221
# 2   서울  2015   257  380  1891  2863   634    2228
# 3   서울  2016   236  355  1878  2903   605    2299
# 4   서울  2017   232  345  1847  2972   592    2380
# 5   서울  2018   214  327  1761  3032   599    2433
# 6   서울  2019   221  324  1688  3086   595    2491
# 7   서울  2020   211  305  1639  3137   629    2509
# 8   서울  2021   188  299  1644  3181   643    2539
# 9   서울  2022   178  265  1632  3220   618    2603
# 10  서울  2023   150  244  1595  3331   612    2719

# %%
gyeongi
# Out:
#    시도별    시점  초졸이하   중졸    고졸  대졸이상  전문대졸  대학교졸이상
# 84  경기  2013   374  476  2566  2783   860    1923
# 85  경기  2014   385  470  2729  2904   838    2066
# 86  경기  2015   352  465  2781  3055   875    2180
# 87  경기  2016   315  454  2813  3187   922    2264
# 88  경기  2017   300  458  2935  3261   977    2283
# 89  경기  2018   297  451  2917  3394   977    2417
# 90  경기  2019   314  458  2952  3502   992    2510
# 91  경기  2020   290  444  2899  3560   985    2575
# 92  경기  2021   269  452  2970  3731  1046    2685
# 93  경기  2022   252  463  3124  3969  1153    2816
# 94  경기  2023   248  386  3103  4122  1158    2964

# %%
daegu
# Out:
#    시도별    시점  초졸이하   중졸   고졸  대졸이상  전문대졸  대학교졸이상
# 22  대구  2013    94  132  458   561   215     346
# 23  대구  2014    95  110  489   581   208     373
# 24  대구  2015    85  113  468   626   215     411
# 25  대구  2016    89  117  473   623   228     394
# 26  대구  2017    84  116  462   630   222     408
# 27  대구  2018    89  106  465   622   210     412
# 28  대구  2019    86  100  438   643   199     444
# 29  대구  2020    85   98  407   642   194     447
# 30  대구  2021    83   88  412   682   226     456
# 31  대구  2022    72   97  429   668   219     448
# 32  대구  2023    71   88  442   685   229     457

# %%
seogyoengdae=pd.concat([seoul,gyeongi,daegu])

# %%
ax=sns.barplot(data=seoul,x='시점',y='대학교졸이상')
ax.bar_label(ax.containers[0])
ax.set_title("서울 대학교졸이상 취업자 수(천명)")
plt.show()

# %%
ax=sns.barplot(data=busan,x='시점',y='대학교졸이상')
ax.bar_label(ax.containers[0])
ax.set_title("부산 대학교졸이상 취업자 수(천명)")
plt.show()

# %%
ax=sns.barplot(data=daegu,x='시점',y='대학교졸이상')
ax.bar_label(ax.containers[0])
ax.set_title("대구 대학교졸이상 취업자 수(천명)")
plt.show()

# %%
ax=sns.barplot(data=incheon,x='시점',y='대졸이상')
ax.bar_label(ax.containers[0])
ax.set_title("인천 대졸이상 취업자 수(천명)")
plt.show()

# %%
ax=sns.barplot(data=incheon,x='시점',y='고졸')
ax.bar_label(ax.containers[0])
ax.set_title("인천 고졸 취업자 수(천명)")
plt.show()

# %%
plt.figure(figsize=(20,20))
ax=sns.barplot(data=seogyoengdae,x='시점',y='대졸이상',hue='시도별',width=1)
ax.bar_label(ax.containers[0])
ax.set_title("전국 대학교졸이상  시도별 취업자 수(천명)")
plt.show()

# %%
plt.figure(figsize=(20,20))
ax=sns.barplot(data=seogyoengdae,x='시점',y='고졸',hue='시도별',width=1)
ax.bar_label(ax.containers[0])
ax.set_title("전국 고졸  시도별 취업자 수(천명)")
plt.show()

# %%
plt.figure(figsize=(20,20))
ax=sns.barplot(data=study2,x='시점',y='대졸이상',hue='시도별',width=1)
ax.bar_label(ax.containers[0])
ax.set_title("전국 대학교졸이상  시도별 취업자 수(천명)")
plt.show()

# %%
plt.figure(figsize=(20,20))
ax=sns.barplot(data=study2,x='시점',y='고졸',hue='시도별',width=1)
ax.bar_label(ax.containers[0])
ax.set_title("전국 고졸  시도별 취업자 수(천명)")
plt.show()

# %%
# 성별 분류

# %%
file3='../SQL/data/mf1.csv'

# %%
malefemale=pd.read_csv(file3)
malefemale
# Out:
#         시도별  성별  2013  2014  2015  2016  2017  2018  2019  2020  2021  2022  \
# 0     서울특별시  남자  2891  2921  2896  2872  2849  2786  2774  2747  2736  2759
# 1     서울특별시  여자  2254  2288  2269  2274  2304  2295  2313  2305  2319  2355
# 2     부산광역시  남자   959   975   962   957   961   935   927   910   922   935
# 3     부산광역시  여자   711   718   722   729   724   722   749   730   736   744
# 4     대구광역시  남자   682   702   715   709   691   680   690   679   689   692
# 5     대구광역시  여자   523   524   532   538   548   546   529   505   528   536
# 6     인천광역시  남자   844   857   865   883   888   902   899   890   896   922
# 7     인천광역시  여자   604   616   623   637   645   672   682   669   667   692
# 8     광주광역시  남자   402   418   423   420   418   419   422   416   418   422
# 9     광주광역시  여자   305   314   311   310   326   330   328   332   327   328
# 10    대전광역시  남자   431   445   443   441   438   431   441   443   446   455
# ...

# %%
malefemaleMulti=malefemale.set_index(['시도별','성별'])
malefemaleMulti
# Out:
#             2013  2014  2015  2016  2017  2018  2019  2020  2021  2022  2023
# 시도별     성별
# 서울특별시   남자  2891  2921  2896  2872  2849  2786  2774  2747  2736  2759  2772
#         여자  2254  2288  2269  2274  2304  2295  2313  2305  2319  2355  2402
# 부산광역시   남자   959   975   962   957   961   935   927   910   922   935   947
#         여자   711   718   722   729   724   722   749   730   736   744   744
# 대구광역시   남자   682   702   715   709   691   680   690   679   689   692   698
#         여자   523   524   532   538   548   546   529   505   528   536   549
# 인천광역시   남자   844   857   865   883   888   902   899   890   896   922   938
#         여자   604   616   623   637   645   672   682   669   667   692   717
# 광주광역시   남자   402   418   423   420   418   419   422   416   418   422   425
#         여자   305   314   311   310   326   330   328   332   327   328   343
# 대전광역시   남자   431   445   443   441   438   431   441   443   446   455   449
# ...

# %%
malefemale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시도별     34 non-null     object
#  1   성별      34 non-null     object
#  2   2013    34 non-null     object
#  3   2014    34 non-null     object
#  4   2015    34 non-null     object
#  5   2016    34 non-null     object
#  6   2017    34 non-null     int64
#  7   2018    34 non-null     int64
#  8   2019    34 non-null     int64
#  9   2020    34 non-null     int64
#  10  2021    34 non-null     int64
#  11  2022    34 non-null     int64
#  12  2023    34 non-null     int64
# dtypes: int64(7), object(6)
# memory usage: 3.6+ KB

# %%
malefemale=malefemale.replace('-',0)

# %%
malefemale['2013'].astype('int64')
malefemale = malefemale.astype({'2013': 'int64','2014': 'int64','2015': 'int64','2016': 'int64'})

# %%
plt.figure(figsize=(20,20))
ax=sns.barplot(data=malefemale,x='시도별',y='2013',hue='성별')
ax.bar_label(ax.containers[0])
ax.set_title("2013 성별에 따른 시도별 취업자 수(천명)")
plt.show()

# %%
plt.figure(figsize=(20,20))
ax=sns.barplot(data=malefemale,x='시도별',y='2014',hue='성별')
ax.bar_label(ax.containers[0])
ax.set_title("2023 성별에 따른 시도별 취업자 수(천명)")
plt.show()

# %%
plt.figure(figsize=(20,20))
ax=sns.barplot(data=malefemale,x='시도별',y='2023',hue='성별')
ax.bar_label(ax.containers[0])
ax.set_title("2023 성별에 따른 시도별 취업자 수(천명)")
plt.show()

# %%
#table 사용

# %%
tablefile='../SQL/data/timesymbol1.csv'

# %%
timesymbol1=pd.read_csv(tablefile)

# %%
timesymbol1
# Out:
#     성별     취업시간별  2013  2014  2015  2016  2017  2018  2019  2020  2021  2022  \
# 0   남자     일시휴직자   163   167   158   154   136   159   163   338   216   219
# 1   남자   54시간 이상  3698  4028  3896  3662  3532  3000  2673  2243  2099  1977
# 2   남자   45-53시간  3908  4327  4491  4405  4473  4190  4171  3673  3625  3504
# 3   남자   36-44시간  4904  4959  5046  5260  5515  5918  6372  6667  6843  6721
# 4   남자   18-35시간  1637  1144  1116  1297  1210  1553  1427  1729  1952  2662
# 5   남자    1-17시간   436   433   449   463   505   552   658   731   814   846
# 6   여자     일시휴직자   251   246   248   259   246   244   244   499   273   264
# 7   여자   54시간 이상  1759  1880  1849  1699  1648  1387  1251  1008   919   879
# 8   여자   45-53시간  2060  2227  2321  2279  2317  2046  1951  1621  1600  1550
# 9   여자   36-44시간  3827  4080  4163  4205  4447  4668  4897  4899  4993  4948
# 10  여자   18-35시간  1925  1667  1673  1923  1842  2137  2155  2326  2602  3115
# ...

# %%
timesymbol1.set_index('성별')
# Out:
#        취업시간별  2013  2014  2015  2016  2017  2018  2019  2020  2021  2022  2023
# 성별
# 남자     일시휴직자   163   167   158   154   136   159   163   338   216   219   181
# 남자   54시간 이상  3698  4028  3896  3662  3532  3000  2673  2243  2099  1977  2053
# 남자   45-53시간  3908  4327  4491  4405  4473  4190  4171  3673  3625  3504  3611
# 남자   36-44시간  4904  4959  5046  5260  5515  5918  6372  6667  6843  6721  7352
# 남자   18-35시간  1637  1144  1116  1297  1210  1553  1427  1729  1952  2662  1906
# 남자    1-17시간   436   433   449   463   505   552   658   731   814   846   849
# 여자     일시휴직자   251   246   248   259   246   244   244   499   273   264   245
# 여자   54시간 이상  1759  1880  1849  1699  1648  1387  1251  1008   919   879   927
# 여자   45-53시간  2060  2227  2321  2279  2317  2046  1951  1621  1600  1550  1687
# 여자   36-44시간  3827  4080  4163  4205  4447  4668  4897  4899  4993  4948  5565
# 여자   18-35시간  1925  1667  1673  1923  1842  2137  2155  2326  2602  3115  2621
# ...

# %%
plt.figure(figsize=(20,20))
ax=sns.barplot(data=timesymbol1,x='취업시간별',y='2013',hue='성별')
ax.bar_label(ax.containers[0])
ax.set_title("2013년도 성별과 취업시간별 취업자 수(천명)")
plt.show()

# %%
plt.figure(figsize=(20,20))
ax=sns.barplot(data=timesymbol1,x='취업시간별',y='2023',hue='성별')
ax.bar_label(ax.containers[0])
ax.set_title("2023년도 성별과 취업시간별 취업자 수(천명)")
plt.show()
